# %% [markdown]
# #### Pipeline / Modular structure

# %% [markdown]
# 1. Step - 1 : Data Ingestion
# 2. Step - 2 : Prepare Base Model (CNN) - transfer-learning-VGG19
# 3. Step - 3 : Model training
# 4. Step - 4 : Model Evaluation
# 5. Step - 5 : Deployement / MLflow

# %% [markdown]
# #### This steps is for all above pipeline Steps:
# 1. Updateconfig.yaml
# 2. params.yaml (optional)
# 3. update entity
# 4. update configuration manager
# 5. update components
# 6. pipeline
# 7. main.py
#
# #### After 4 pipeline >> update dvc.yaml and app.py
